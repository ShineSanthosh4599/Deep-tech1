.7503878338377146, 1.7010179302965738, 1.6533710939588857, 1.6073869635961264, 1.563007292634073, 1.5201758750693821, 1.47883847398154, 1.4389427525492813, 1.40043820748376, 1.363276104793746, 1.3274094178011995, 1.2927927673283628, 1.2593823639803086, 1.227135952449507, 1.1960127577716095, 1.1659734334640486, 1.136980011481552, 1.108995853924838, 1.081985606441164, 1.0559151532573743, 1.0307515737883042, 1.0064631007653415, 0.9830190798318822, 0.9603899305542801, 0.9385471087987391, 0.9174630704262495, 0.897111236259412, 0.8774659582766045, 0.8585024869904686, 0.8401969399692507, 0.8225262714609155, 0.8054682430814813, 0.7890013955301842, 0.773105021295595, 0.7577591383179129, 0.7429444645739625, 0.7286423935525722, 0.7148349705891076, 0.7015048700291231, 0.6886353731920093, 0.6762103471066746, 0.6642142239921647, 0.6526319814571783, 0.6414 ...

# %% [markdown]
# This trained model is showing vast improvements after it’s full training cycle. We can examine further by inspecting its final predicted coefficients $a$, $b$ and $c$.

# %%
print(f"Final Coefficients predicted: {GD[1]}")
print(f"Original Coefficients: {coeffs}")
# Out:
# Final Coefficients predicted: (0.9997071180425983, -0.0011140960028969882, 0.010081453347458549)
# Original Coefficients: [1, 0, 0]

# %% [markdown]
# Not too far off! A big improvement over the initial random model. Looking at the plot of the loss reduction over training offers further insights.

# %%
plt.figure(figsize=(12, 6))
plt.plot(GD[3], 'b-', label = 'loss')
plt.title('Loss over 500 iterations')
plt.legend(loc="lower right")
plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# We observe that the model loss reached close to zero, to give us our more accurate coefficients. We can also see there was no major improvement in loss after about 100 epochs. An alternative strategy would be to add some kind of condition to the training step that stops training when a certain minimum loss threshold has been reached. This would prevent excessive training and potential over-fitting for the model.

# %% [markdown]
# # Things to try
#
#
#
# 1.   Change the coefficients array and try a different polynomial instead of our $x^2$.
# 2.   Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?
# 3. Take a degree 5 polynomial with 5 roots and try different initializations, instead of random ones. Does it converge on different values for different initializations? Why does initialization not matter in our case of $x^2$?
# 4. Can you modify the algorithm to find a maxima of a function, instead of a minima?

# %% [markdown]
# Answers

# %% [markdown]
# 1.

# %%
def eval_cubic_degree(coeffs, x):

    a = coeffs[0] * (x ** 3)
    b = coeffs[1] * (x ** 2)
    c = coeffs[2] * x
    d = coeffs[3]
    y = a + b + c + d

    return y

# %%
cubic_coeffs = (random.randrange(-10, 10), random.randrange(-10, 10), random.randrange(-10, 10), random.randrange(-10, 10))
xs_values = np.random.uniform(-10, 10, 100)


xs_cubic = []
ys_cubic = []
for x in xs_values:
    y = eval_cubic_degree(cubic_coeffs, x)
    xs_cubic.append(x)
    ys_cubic.append(y)

plt.figure(figsize=(8, 6))
plt.plot(xs_cubic, ys_cubic, 'g+')
plt.title('cubic polynomial data')
plt.show()

# %%
rand_coeffs = (random.randrange(-10, 10), random.randrange(-10, 10), random.randrange(-10, 10))
y_bar = eval_2nd_degree(rand_coeffs, xs_values)

plt.figure(figsize=(8, 6))
plt.plot(xs, ys, 'g+', label = 'original data')
plt.plot(xs_cubic, y_bar, 'r.', label = 'prediction data')
plt.title('Original data vs first prediction')
plt.legend(loc="lower right")
plt.show()

# %%
initial_model_loss = loss_mse(ys, y_bar)
print(initial_model_loss)
# Out:
# 273295.57203885476

# %% [markdown]
# 2.

# %%
learning_rates = [0.001, 0.01, 0.1]

results = []

for lr in learning_rates:

    rand_coeffs = (random.randrange(-10, 10), random.randrange(-10, 10), random.randrange(-10, 10))

    GD = gradient_descent(50000, lr) # Output of GD function: (updated_model_loss, new_model_coeffs, new_y_bar, list_of_loss_updates)

    results.append((lr, GD[3])) # (learning rate, list_of_loss_updates)

# Plot the loss updates for different learning rates
plt.figure(figsize=(8, 4))
for lr, losses in results:
    plt.plot(losses, label=f'LR: {lr}')

plt.title('Loss updates for different learning rates')
plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# <ipython-input-29-3e15a3826a00>:12: RuntimeWarning: overflow encountered in double_scalars
#   return sum((ys - y_bar) * (ys - y_bar)) / len(ys)
# <ipython-input-29-3e15a3826a00>:12: RuntimeWarning: overflow encountered in multiply
#   return sum((ys - y_bar) * (ys - y_bar)) / len(ys)
# <ipython-input-35-bad7532be911>:32: RuntimeWarning: overflow encountered in double_scalars
#   gradient_a = (-2 / n) * sum(a_s)
# <ipython-input-35-bad7532be911>:33: RuntimeWarning: invalid value encountered in double_scalars
#   gradient_b = (-2 / n) * sum(b_s)
# <ipython-input-35-bad7532be911>:37: RuntimeWarning: invalid value encountered in double_scalars
#   a_new = coeffs[0] - lr * gradient_a
# [72552.7510619374, 347839.0661484348, 1693725.9422312623, 8270770.988397534, 40408599.88246116, 197443299.98373267, 964758010.6338838, 4714066729.332324, 23034208903.82759, 112551404992.84477, 549956764373.2603, 2687238277536.492, 13130576860612.342, 64159568636902.36, 313501096825616.7, 1531851597497947.8, 7485043403416879.0, 3.6573957191774504e+16, 1.787102990017597e+17, 8.73227110805532e+17, 4.266825086775044e+18, 2.0848867489167245e+19, 1.0187323519028775e+20, 4.9778032564732966e+20, 2.4322900135519044e+21, 1.1884830326170346e+22, 5.807251236277948e+22, 2.837580848503266e+23, 1.3865191541038301e+24, 6.774909570279986e+24, 3.310405020343062e+25, 1.617553900171048e+26, 7.903808156040749e+26, 3.862015563184038e+27, 1.887085809247064e+28, 9.2208143473293e+28, 4.5055405965793166e+29, 2.2015296374884645e+30, 1.0757272386847008e+31, 5.256295769737403e+31, 2.568369027518634e+32, 1.2549749387193569e+33, 6.132148768104653e+33, 2.996334616254549e+34, 1.4640905614134772e+35, 7.153944557432322e+35, 3.4956118207200165e+36, 1.7080509784581334e+37, 8.346001485974104e+37, 4.0780832470679725e+38, 1.9926623542980866e+39,
+305, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan ...

# %% [markdown]
# 3.

# %%
def eval_fifth_degree(coeffs, x):

    a = coeffs[0] * (x ** 5)
    b = coeffs[1] * (x ** 4)
    c = coeffs[2] * (x ** 3)
    d = coeffs[3] * (x ** 2)
    e = coeffs[4] * x
    f = coeffs[5]

    y = a + b + c + d + e + f

    return y

# %%
def calc_gradient_5th_poly_for_GD(coeffs, inputs_x, outputs_y, lr):

    a_s = []
    b_s = []
    c_s = []
    d_s = []
    e_s = []
    f_s = []

    y_bars = eval_fifth_degree(coeffs, inputs_x)

    for x,y,y_bar in list(zip(inputs_x, outputs_y, y_bars)):    # take tuple of (x datapoint, actual y label, predicted y label)

        partial_a = x**5 * (y - y_bar)
        a_s.append(partial_a)
        partial_b = x**4 * (y - y_bar)
        b_s.append(partial_b)
        partial_c = x**3 * (y - y_bar)
        c_s.append(partial_c)
        partial_d = x**2 * (y - y_bar)
        d_s.append(partial_d)
        partial_e = x * (y - y_bar)
        e_s.append(partial_e)
        partial_f = (y - y_bar)
        f_s.append(partial_f)

    num = [i for i in y_bars]
    n = len(num)

    gradient_a = (-2 / n) * sum(a_s)
    gradient_b = (-2 / n) * sum(b_s)
    gradient_c = (-2 / n) * sum(c_s)
    gradient_d = (-2 / n) * sum(d_s)
    gradient_e = (-2 / n) * sum(e_s)
    gradient_f = (-2 / n) * sum(f_s)


    a_new = coeffs[0] - lr * gradient_a
    b_new = coeffs[1] - lr * gradient_b
    c_new = coeffs[2] - lr * gradient_c
    d_new = coeffs[3] - lr * gradient_d
    e_new = coeffs[4] - lr * gradient_e
    f_new = coeffs[5] - lr * gradient_f

    new_model_coeffs = (a_new, b_new, c_new, d_new, e_new, f_new)

    # updating with these new coeffs:
    new_y_bar = eval_fifth_degree(new_model_coeffs, inputs_x)

    updated_model_loss = loss_mse(outputs_y, new_y_bar)

    return updated_model_loss, new_model_coeffs, new_y_bar

# %%
# Random initializations

hundred_xs_new = np.array([random.randint(0, x+2) for x in range(100)])
coeffs = [random.randint(0, x+2) for x in range(6)]

xs_new = []
ys_new = []
for x in hundred_xs_new:
    y  = eval_fifth_degree(coeffs, x)
    xs_new.append(x)
    ys_new.append(y)

# %%
print(type(hundred_xs_new), type(coeffs))
# Out:
# <class 'numpy.ndarray'> <class 'list'>

# %%
def gradient_descent_fifth(epochs, lr):

    losses = []
    rand_coeffs_to_test = coeffs
    for i in range(epochs):
        loss = calc_gradient_5th_poly_for_GD(rand_coeffs_to_test, hundred_xs_new, ys_new, lr)
        rand_coeffs_to_test = loss[1]
        losses.append(loss[0])
    return loss[0], loss[1], loss[2], losses  # (updated_model_loss, new_model_coeffs, new_y_bar, saved loss updates)

# %%
GD_fifth = gradient_descent_fifth(30000, 0.0003)

plt.figure(figsize=(8, 6))
plt.plot(xs_new, ys_new, 'g+', label = 'original')
plt.plot(xs_new, GD_fifth[2], 'b*', label = 'final_prediction')
plt.title('Original vs Final prediction after Gradient Descent')
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# In the case of x^2, it's a convex function with a single global minimum, and there are no local minima. This is why different initializations converge to the same minimum, and the choice of initialization does not matter.

# %% [markdown]
# 4.

# %%
# Random initializations

hundred_xs = np.random.uniform(-10, 10, 100)
coeffs = [1, 2, 0, 1, 1, 1]

xs_new = []
ys_new = []
for x in hundred_xs_new:
    y  = eval_fifth_degree(coeffs, x)
    xs_new.append(x)
    ys_new.append(y)

# %%
# gradient calculation
def calc_gradient_5th_poly_for_GD_max(coeffs, inputs_x, outputs_y, lr):

    a_s = []
    b_s = []
    c_s = []
    d_s = []
    e_s = []
    f_s = []

    y_bars = eval_fifth_degree(coeffs, inputs_x)

    for x, y, y_bar in zip(inputs_x, outputs_y, y_bars):

        # -ve sign is to move in the direction of a maximum
        partial_a = -x**5 * (y - y_bar)
        a_s.append(partial_a)
        partial_b = -x**4 * (y - y_bar)
        b_s.append(partial_b)
        partial_c = -x**3 * (y - y_bar)
        c_s.append(partial_c)
        partial_d = -x**2 * (y - y_bar)
        d_s.append(partial_d)
        partial_e = -x * (y - y_bar)
        e_s.append(partial_e)
        partial_f = -(y - y_bar)
        f_s.append(partial_f)

    num = [i for i in y_bars]
    n = len(num)

    gradient_a = (-2 / n) * sum(a_s)
    gradient_b = (-2 / n) * sum(b_s)
    gradient_c = (-2 / n) * sum(c_s)
    gradient_d = (-2 / n) * sum(d_s)
    gradient_e = (-2 / n) * sum(e_s)
    gradient_f = (-2 / n) * sum(f_s)

    # + sign t change rule
    a_new = coeffs[0] + lr * gradient_a
    b_new = coeffs[1] + lr * gradient_b
    c_new = coeffs[2] + lr * gradient_c
    d_new = coeffs[3] + lr * gradient_d
    e_new = coeffs[4] + lr * gradient_e
    f_new = coeffs[5] + lr * gradient_f

    new_model_coeffs = (a_new, b_new, c_new, d_new, e_new, f_new)
    new_y_bar = eval_fifth_degree(new_model_coeffs, inputs_x)
    updated_model_loss = loss_mse(outputs_y, new_y_bar)

    return updated_model_loss, new_model_coeffs, new_y_bar

# %%
# Gradient descent function for finding a maximum

def gradient_descent_fifth_max(epochs, lr):
    losses = []
    rand_coeffs_to_test = coeffs
    for i in range(epochs):
        loss = calc_gradient_5th_poly_for_GD_max(rand_coeffs_to_test, hundred_xs_new, ys, lr)
        rand_coeffs_to_test = loss[1]
        losses.append(loss[0])
    return loss[0], loss[1], loss[2], losses # (updated_model_loss, new_model_coeffs, new_y_bar, saved loss updates)

# %%
GD_ = gradient_descent_fifth_max(30000, 0.0001)

plt.figure(figsize=(8, 6))
plt.plot(xs_new, ys_new, 'g+', label = 'original')
plt.plot(xs_new, GD_[2], 'b*', label = 'final_prediction')
plt.title('Original vs Final prediction after Gradient Descent')
plt.legend(loc = "lower right")
plt.show()
# Out:
# <ipython-input-29-3e15a3826a00>:12: RuntimeWarning: overflow encountered in multiply
#   return sum((ys - y_bar) * (ys - y_bar)) / len(ys)
# <ipython-input-29-3e15a3826a00>:12: RuntimeWarning: overflow encountered in double_scalars
#   return sum((ys - y_bar) * (ys - y_bar)) / len(ys)
# <ipython-input-52-7f39544f5634>:16: RuntimeWarning: overflow encountered in double_scalars
#   partial_a = -x**5 * (y - y_bar)
# <ipython-input-52-7f39544f5634>:18: RuntimeWarning: overflow encountered in double_scalars
#   partial_b = -x**4 * (y - y_bar)
# <ipython-input-52-7f39544f5634>:32: RuntimeWarning: overflow encountered in double_scalars
#   gradient_a = (-2 / n) * sum(a_s)
# <ipython-input-52-7f39544f5634>:33: RuntimeWarning: overflow encountered in double_scalars
#   gradient_b = (-2 / n) * sum(b_s)
# <ipython-input-45-fd8af10daf41>:3: RuntimeWarning: invalid value encountered in multiply
#   a = coeffs[0] * (x ** 5)
# <ipython-input-45-fd8af10daf41>:4: RuntimeWarning: invalid value encountered in multiply
#   b = coeffs[1] * (x ** 4)

# %%
# loss history

plt.figure(figsize=(10, 4))
plt.plot(GD[3], 'b-', label = 'loss')
plt.title('Loss over 30000 iterations')

plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.legend(loc="lower right")
plt.show()
